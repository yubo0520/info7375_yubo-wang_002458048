# %% [markdown]
# # TinyZero Countdown LoRA

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install -U peft trl transformers datasets accelerate -q

# %%
from google.colab import files
files.upload()

# %%
# !python /content/train.py
